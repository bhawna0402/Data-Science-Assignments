# %% [markdown]
# # 📊 Week 1 Assignment: Student Marks Data Analysis
#
# This notebook demonstrates basic data analysis using Python, Pandas, and Matplotlib.
#
# Objectives:
# - Load dataset from CSV file
# - Perform descriptive statistical analysis
# - Visualize score distribution using histogram
# - Interpret insights from data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load dataset
df = pd.read_csv("student_marks.csv")
df.head()

df_display = df.copy()

# Start index from 0
df_display.index = df_display.index+1

# Reset index so S.No becomes a proper column (fixes blank row issue)
df_display = df_display.reset_index()

# Rename index column to S.No
df_display = df_display.rename(columns={"index": "S.No"})

# Display professional table with full borders
df_display.style \
    .set_caption("Student Marks Dataset") \
    .hide(axis="index") \
    .set_table_styles([
        {
            'selector': 'table',
            'props': [
                ('border', '2px solid black'),
                ('border-collapse', 'collapse'),
                ('width', '70%'),
                ('margin', '20px auto'),
                ('font-size', '14px')
            ]
        },
        {
            'selector': 'th',
            'props': [
                ('border', '1px solid black'),
                ('padding', '8px'),
                ('text-align', 'center'),
                ('background-color', '#e6e6e6'),
                ('font-weight', 'bold')
            ]
        },
        {
            'selector': 'td',
            'props': [
                ('border', '1px solid black'),
                ('padding', '8px'),
                ('text-align', 'center')
            ]
        },
        {
            'selector': 'caption',
            'props': [
                ('caption-side', 'top'),
                ('font-size', '18px'),
                ('font-weight', 'bold'),
                ('padding', '10px')
            ]
        }
    ])
# Out:
# <style type="text/css">
# #T_a0225 table {
#   border: 2px solid black;
#   border-collapse: collapse;
#   width: 70%;
#   margin: 20px auto;
#   font-size: 14px;
# }
# #T_a0225 th {
#   border: 1px solid black;
#   padding: 8px;
#   text-align: center;
#   background-color: #e6e6e6;
#   font-weight: bold;
# }
# #T_a0225 td {
#   border: 1px solid black;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0225 caption {
#   caption-side: top;
#   font-size: 18px;
#   font-weight: bold;
#   padding: 10px;
# }
# </style>
# <table id="T_a0225">
#   <caption>Student Marks Dataset</caption>
#   <thead>
#     <tr>
#       <th id="T_a0225_level0_col0" class="col_heading level0 col0" >S.No</th>
#       <th id="T_a0225_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a0225_level0_col2" class="col_heading level0 col2" >Maths</th>
#       <th id="T_a0225_level0_col3" class="col_heading level0 col3" >Science</th>
#       <th id="T_a0225_level0_col4" class="col_heading level0 col4" >English</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0225_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a0225_row0_col1" class="data row0 col1" >Aman</td>
#       <td id="T_a0225_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_a0225_row0_col3" class="data row0 col3" >85</td>
#       <td id="T_a0225_row0_col4" class="data row0 col4" >82</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a0225_row1_col1" class="data row1 col1" >Riya</td>
#       <td id="T_a0225_row1_col2" class="data row1 col2" >90</td>
#       <td id="T_a0225_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_a0225_row1_col4" class="data row1 col4" >91</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a0225_row2_col1" class="data row2 col1" >Rahul</td>
#       <td id="T_a0225_row2_col2" class="data row2 col2" >65</td>
#       <td id="T_a0225_row2_col3" class="data row2 col3" >70</td>
#       <td id="T_a0225_row2_col4" class="data row2 col4" >60</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a0225_row3_col1" class="data row3 col1" >Simran</td>
#       <td id="T_a0225_row3_col2" class="data row3 col2" >88</td>
#       <td id="T_a0225_row3_col3" class="data row3 col3" >92</td>
#       <td id="T_a0225_row3_col4" class="data row3 col4" >85</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a0225_row4_col1" class="data row4 col1" >Karan</td>
#       <td id="T_a0225_row4_col2" class="data row4 col2" >72</td>
#       <td id="T_a0225_row4_col3" class="data row4 col3" >75</td>
#       <td id="T_a0225_row4_col4" class="data row4 col4" >70</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a0225_row5_col1" class="data row5 col1" >Neha</td>
#       <td id="T_a0225_row5_col2" class="data row5 col2" >95</td>
#       <td id="T_a0225_row5_col3" class="data row5 col3" >89</td>
#       <td id="T_a0225_row5_col4" class="data row5 col4" >94</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a0225_row6_col1" class="data row6 col1" >Arjun</td>
#       <td id="T_a0225_row6_col2" class="data row6 col2" >60</td>
#       <td id="T_a0225_row6_col3" class="data row6 col3" >65</td>
#       <td id="T_a0225_row6_col4" class="data row6 col4" >58</td>
#     </tr>
#     <tr>
#       <td id="T_a0225_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a0225_row7_col1" class="data row7 col1" >Priya</td>
#       <td id="T_a0225_row7_col2" class="data row7 col2" >85</td>
#       <td id="T_a0225_row7_col3" class="data row7 col3" >80</td>
#       <td id="T_a0225_row7_col4" class="data row7 col4" >87</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Descriptive Statistics

# Select numeric columns
numeric_df = df[['Maths', 'Science', 'English']]

# Create professional descriptive statistics table
desc_stats = pd.DataFrame({
    "Subject": numeric_df.columns,
    "Mean": numeric_df.mean().values,
    "Median": numeric_df.median().values,
    "Mode": numeric_df.mode().iloc[0].values,
    "Standard Deviation": numeric_df.std().values
})

# Apply professional styling with borders and colors
desc_stats.style \
    .set_caption("Descriptive Statistical Summary of Student Marks") \
    .hide(axis="index") \
    .format({
        "Mean": "{:.2f}",
        "Median": "{:.2f}",
        "Mode": "{:.0f}",
        "Standard Deviation": "{:.2f}"
    }) \
    .set_table_styles([
        {'selector': 'table', 'props': [
            ('border', '2px solid black'),
            ('border-collapse', 'collapse'),
            ('width', '70%'),
            ('text-align', 'center')
        ]},
        {'selector': 'th', 'props': [
            ('border', '1px solid black'),
            ('padding', '10px'),
            ('background-color', '#d9ead3'),
            ('font-weight', 'bold')
        ]},
        {'selector': 'td', 'props': [
            ('border', '1px solid black'),
            ('padding', '8px')
        ]},
        {'selector': 'caption', 'props': [
            ('font-size', '18px'),
            ('font-weight', 'bold'),
            ('padding', '10px')
        ]}
    ])
# Out:
# <style type="text/css">
# #T_a8b4f table {
#   border: 2px solid black;
#   border-collapse: collapse;
#   width: 70%;
#   text-align: center;
# }
# #T_a8b4f th {
#   border: 1px solid black;
#   padding: 10px;
#   background-color: #d9ead3;
#   font-weight: bold;
# }
# #T_a8b4f td {
#   border: 1px solid black;
#   padding: 8px;
# }
# #T_a8b4f caption {
#   font-size: 18px;
#   font-weight: bold;
#   padding: 10px;
# }
# </style>
# <table id="T_a8b4f">
#   <caption>Descriptive Statistical Summary of Student Marks</caption>
#   <thead>
#     <tr>
#       <th id="T_a8b4f_level0_col0" class="col_heading level0 col0" >Subject</th>
#       <th id="T_a8b4f_level0_col1" class="col_heading level0 col1" >Mean</th>
#       <th id="T_a8b4f_level0_col2" class="col_heading level0 col2" >Median</th>
#       <th id="T_a8b4f_level0_col3" class="col_heading level0 col3" >Mode</th>
#       <th id="T_a8b4f_level0_col4" class="col_heading level0 col4" >Standard Deviation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a8b4f_row0_col0" class="data row0 col0" >Maths</td>
#       <td id="T_a8b4f_row0_col1" class="data row0 col1" >79.12</td>
#       <td id="T_a8b4f_row0_col2" class="data row0 col2" >81.50</td>
#       <td id="T_a8b4f_row0_col3" class="data row0 col3" >60</td>
#       <td id="T_a8b4f_row0_col4" class="data row0 col4" >12.54</td>
#     </tr>
#     <tr>
#       <td id="T_a8b4f_row1_col0" class="data row1 col0" >Science</td>
#       <td id="T_a8b4f_row1_col1" class="data row1 col1" >80.50</td>
#       <td id="T_a8b4f_row1_col2" class="data row1 col2" >82.50</td>
#       <td id="T_a8b4f_row1_col3" class="data row1 col3" >65</td>
#       <td id="T_a8b4f_row1_col4" class="data row1 col4" >9.72</td>
#     </tr>
#     <tr>
#       <td id="T_a8b4f_row2_col0" class="data row2 col0" >English</td>
#       <td id="T_a8b4f_row2_col1" class="data row2 col1" >78.38</td>
#       <td id="T_a8b4f_row2_col2" class="data row2 col2" >83.50</td>
#       <td id="T_a8b4f_row2_col3" class="data row2 col3" >58</td>
#       <td id="T_a8b4f_row2_col4" class="data row2 col4" >13.93</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 📊 Visualization of Student Marks Distribution
#
# This section uses histograms and a bar graph to visualize student marks and support statistical analysis.
#
# ### Histogram
# - Shows the distribution and spread of marks across Maths, Science, and English
# - Helps understand score frequency and variation
# - Supports analysis of overall performance patterns
#
# ### Bar Graph
# - Displays the average marks for each subject
# - Helps compare overall performance between Maths, Science, and English
# - Clearly highlights differences in subject-wise performance

# %%
import matplotlib.pyplot as plt
import numpy as np

bins = [50, 60, 70, 80, 90, 100]

plt.figure(figsize=(10,6))

plt.hist([df['Maths'], df['Science'], df['English']],
         bins=bins,
         label=['Maths', 'Science', 'English'],
         edgecolor='black')

plt.title("Histogram of Student Marks Distribution by Subject",
          fontsize=16, fontweight='bold')

plt.xlabel("Marks Range", fontsize=12)
plt.ylabel("Number of Students", fontsize=12)

plt.xticks(bins)

plt.legend(title="Subjects")

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
